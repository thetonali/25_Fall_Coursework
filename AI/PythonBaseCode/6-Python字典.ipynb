# %% [markdown]
# ### 字典结构

# %%
tang = {}
tang
# Out:
# {}

# %%
type(tang)
# Out:
# dict

# %%
tang = dict()
type(tang)
# Out:
# dict

# %%
tang
# Out:
# {}

# %% [markdown]
# ### 字典结构操作
# key - value

# %%
# 赋值方式1-类似数组
tang['first'] = 123
tang
# Out:
# {'first': 123}

# %%
tang['python'] = 456
tang
# tang['python']
# Out:
# {'first': 123, 'python': 456}

# %%
tang['python']
# Out:
# 456

# %%
tang['python'] = 789
tang
# Out:
# {'first': 123, 'python': 789}

# %%
# 赋值方式2-：
tang = {'tang':123,'yu':456,'di':789}
tang
# Out:
# {'tang': 123, 'yu': 456, 'di': 789}

# %%
# tang[0]
tang['yu']
# Out:
# 456

# %%
# 使用了赋值方式1
tang_value = [1,2,3]
tang = {}
# 类似声明tang为字典类型
tang['yudi'] = tang_value
tang['yudi2'] = 3
tang['yudi3'] = '4'
tang['yudi4']=['1',2,[3,4]]
tang[1]=2
# !tang[{1:'lec',2:'key'}]=1-错误
# !tang[[1,2,3]]='test'-错误
tang
# tang[1]
# 字典的键为不可以是列表、不可以是字典类型
# Out:
# {'yudi': [1, 2, 3], 'yudi2': 3, 'yudi3': '4', 'yudi4': ['1', 2, [3, 4]], 1: 2}

# %%
tang = {}
d1 = {'tang':123,'yudi':456}
d2 = {'tang2':456,'yudi2':789}
tang['test1'] = d1
tang['test2'] = d2
tang
# 字典中嵌套字典类型
# Out:
# {'test1': {'tang': 123, 'yudi': 456}, 'test2': {'tang2': 456, 'yudi2': 789}}

# %%
a=[('tang',123),('yudi',456)]

# type(a)-列表
a[0] #('tang', 123)
# todo type(a[0])-元组

tang = dict([('tang',123),('yudi',456)])
# tang = dict(((4,123),('yudi',456))) #也可以
# tang = dict([['test',123],['yudi',456]]) #也可以
tang

# b=((4,123),('yudi',456))
# type(b)
# type(b[0])

# c=[['test',123],['yudi',456]]
# type(c)
# type(c[0])
# Out:
# {'tang': 123, 'yudi': 456}

# %%
tang['tang'] += 1
tang
# Out:
# {'tang': 124, 'yudi': 456}

# %%
tang.get('tang')
# Out:
# 124

# %%
tang['fengzi']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 tang['fengzi']
#
# KeyError: 'fengzi'

# %%
tang.get('fengzi','meiyou')
# Out:
# 'meiyou'

# %%
tang
# Out:
# {'tang': 125, 'yudi': 456}

# %%
tang.pop('tang')
# Out:
# 125

# %%
tang
# Out:
# {'yudi': 456}

# %%
del tang['yudi']
tang
# Out:
# {}

# %%
tang = {'tang':123,'yudi':456}
tang2 = {'tang':789,'python':888}
tang.update(tang2)
tang
# Out:
# {'python': 888, 'tang': 789, 'yudi': 456}

# %%
'tang' in tang
# Out:
# True

# %%
'hello' in tang
# Out:
# False

# %%
tang.keys()
# Out:
# dict_keys(['tang', 'python', 'yudi'])

# %%
type(tang.values())
# Out:
# dict_values

# %%
type(tang.items())
# Out:
# dict_items
