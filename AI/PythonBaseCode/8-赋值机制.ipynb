# %%
tang = 1000
yudi = tang
yudi
# Out:
# 1000

# %%
id(tang)
# Out:
# 2482004008368

# %%
id(yudi)
# Out:
# 2482004008368

# %%
tang is yudi
type(tang)
# Out:
# int

# %%
yudi = 123456

# %%
id(yudi)
# Out:
# 2482004419760

# %%
tang is yudi
# Out:
# False

# %%
tang = 1000
yudi =1000
tang is yudi
# Out:
# False

# %%
id(tang)
# Out:
# 2683811813008

# %%
id(yudi)
# Out:
# 2683811812912

# %%
tang =1
yudi =1

# %%
id(tang)
# Out:
# 1932198384

# %%
id(yudi)
# Out:
# 1932198384
