# %%
# %%writefile tang.py

tang_v = 10

def tang_add(tang_list):
    tang_sum = 0
    for i in range(len(tang_list)):
        tang_sum += tang_list[i]
    return tang_sum
tang_list = [1,2,3,4,5]
print (tang_add(tang_list))
# Out:
# Overwriting tang.py

# %%
# %run tang.py
# Out:
# 15

# %%
import tang

# %%
tang
# Out:
# <module 'tang' from 'e:\\Courses\\25Fall\\AI\\PythonBaseCode\\tang.py'>

# %%
print (tang.tang_v)
# Out:
# 10

# %%
tang.tang_v = 100
tang.tang_v
# Out:
# 100

# %%
tang_list = [10,11,12]
tang.tang_add(tang_list)
# Out:
# 33

# %%
import tang as tg

# %%
tg.tang_v
# Out:
# 100

# %%
tg.tang_add(tang_list)
# Out:
# 33

# %%
from tang import tang_v,tang_add

# %%
tang_v
# Out:
# 100

# %%
tang_add(tang_list)
# Out:
# 33

# %%
from tang import *

# %%
tang_v
# Out:
# 100

# %%
tang_add(tang_list)
# Out:
# 15

# %%
import os
os.remove('tang.py')

# %%
os.path.abspath('.')
# Out:
# 'e:\\Courses\\25Fall\\AI\\PythonBaseCode'
