# %%
import math

for i in range(10):
    input_number = input('write a number')
    if input_number == 'q':
        break
    result = math.log(float(input_number))
    print (result)
# Out:
# 4.48863636973214

# %%
import math

for i in range(10):
    try:
        input_number = input('write a number')
        if input_number == 'q':
            break
        result = math.log(float(input_number))
        print (result)
    except ValueError:
        print ('ValueError: input must > 0')
        #break
# Out:
# ValueError: input must > 0

# %%
import math

for i in range(10):
    try:
        input_number = input('write a number')
        if input_number[0] == 'q':
            break
        result = 1/math.log(float(input_number))
        print (result)
    except ValueError:
        print ('ValueError: input must > 0')
# Out:
# 0.36067376022224085
# 0.1956186206621379
# 0.1970375865745452

# %%
import math

for i in range(10):
    try:
        input_number = input('write a number')
        
        if input_number == 'q':
            break
        result = 1/math.log(float(input_number))
        print (result)
    except ValueError:
        print ('ValueError: input must > 0')
    except ZeroDivisionError:
        print ('log(value) must != 0')
    except Exception:
        print ('ubknow error')
# Out:
# 0.28599966750267436
# 0.36067376022224085
# ValueError: input must > 0
# ValueError: input must > 0
# log(value) must != 0
# ValueError: input must > 0

# %%
class TangError(ValueError):
    pass

cur_list = ['tang','yu','di']
while True:
    cur_input = input()
    if cur_input not in cur_list:
        raise TangError('Invalid input: %s' %cur_input)
# Out:
# ---------------------------------------------------------------------------
# TangError                                 Traceback (most recent call last)
# Cell In[18], line 8
#       6 cur_input = input()
#       7 if cur_input not in cur_list:
# ----> 8     raise TangError('Invalid input: %s' %cur_input)
#
# TangError: Invalid input: qqq

# %%
try:
    print ('hello')
finally:
    print ('finally')
# Out:
# hello
# finally

# %%
try:
    1/0
finally:
    print ('finally')
# Out:
# finally
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 try:
# ----> 2     1/0
#       3 finally:
#       4     print ('finally')
#
# ZeroDivisionError: division by zero

# %%
try:
    1/0
except:
    print ('==0')
finally:
    print ('finally')
# Out:
# ==0
# finally
