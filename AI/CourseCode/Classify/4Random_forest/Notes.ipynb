# %% [markdown]
# ### 集成学习
# 1. 组成
#    - 个体生成方法
#    - 基学习器
#    - 结论合成方法
#
# 3. 同质个体学习器的分类及算法
#    - 分类：是否存在强依赖关系
#      - boosting
#      - bagging、Random forest
#    - (结论合成)算法：投票、简单/加权平均-分类器组合函数

# %% [markdown]
# 1. Voting
# 2. Bagging
#    袋外数据充当测试集。(不需要训练集与测试集的划分)
#    boostrap=True有放回抽样。
# 3. 随机森林
#    基学习器是bagging产生N个训练子集，每个是决策树，共同构成随机森林。
#    oob_score=True
#    max_depth从小一点的值测试。
# 4. boosting->adaboost
