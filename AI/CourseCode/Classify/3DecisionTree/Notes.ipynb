# %% [markdown]
# 决策树
#  -ID3算法(容易出现过拟合->可以剪枝)
#   -信息增益(经验熵-条件经验熵)==>不断重复
#    特征=>决策树的内节点
#  -C4.5算法(sklearn库中没有)
#   -信息增益比
#  -CART算法
#   -二叉树原理(递归构建二叉决策树)
#   -对回归树用平方误差最小化准则;
#   -对分类树用基尼指数(Gini增益最小=>某个特征二分类分别的概率*其Gini指数)
